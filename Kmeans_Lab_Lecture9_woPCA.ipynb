# %% [markdown]
# ## Lab Lecture 9: Analysis of the population receiving Food Stamps
# #### Idea from Kamsey Agu, this was part of her CE 263H_Final Project

# %% [markdown]
# Source: https://geographicdata.science/book/notebooks/10_clustering_and_regionalization.html

# %%
#You will need:
# !pip install geopandas==0.8.2
# !pip install contextily
# !pip install cenpy==1.0.1
# Out:
# Requirement already satisfied: geopandas==0.8.2 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (0.8.2)
# Requirement already satisfied: pandas>=0.23.0 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from geopandas==0.8.2) (1.4.2)
# Requirement already satisfied: fiona in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from geopandas==0.8.2) (1.8.21)
# Requirement already satisfied: pyproj>=2.2.0 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from geopandas==0.8.2) (3.4.0)
# Requirement already satisfied: shapely in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from geopandas==0.8.2) (1.8.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.23.0->geopandas==0.8.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.23.0->geopandas==0.8.2) (2021.3)
# Requirement already satisfied: numpy>=1.18.5 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.23.0->geopandas==0.8.2) (1.21.5)
# Requirement already satisfied: certifi in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from pyproj>=2.2.0->geopandas==0.8.2) (2021.10.8)
# Requirement already satisfied: setuptools in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from fiona->geopandas==0.8.2) (61.2.0)
# Requirement already satisfied: six>=1.7 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from fiona->geopandas==0.8.2) (1.16.0)
# Requirement already satisfied: munch in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from fiona->geopandas==0.8.2) (2.5.0)
# Requirement already satisfied: cligj>=0.5 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from fiona->geopandas==0.8.2) (0.7.2)
# Requirement already satisfied: click>=4.0 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from fiona->geopandas==0.8.2) (8.0.4)
# Requirement already satisfied: click-plugins>=1.0 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from fiona->geopandas==0.8.2) (1.1.1)
# Requirement already satisfied: attrs>=17 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from fiona->geopandas==0.8.2) (21.4.0)
#
# [notice] A new release of pip is available: 23.0 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: contextily in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (1.2.0)
# Requirement already satisfied: pillow in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from contextily) (9.0.1)
# Requirement already satisfied: rasterio in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from contextily) (1.3.2)
# Requirement already satisfied: joblib in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from contextily) (1.1.0)
# Requirement already satisfied: matplotlib in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from contextily) (3.5.1)
# Requirement already satisfied: mercantile in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from contextily) (1.2.1)
# Requirement already satisfied: geopy in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from contextily) (2.2.0)
# Requirement already satisfied: xyzservices in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from contextily) (2022.9.0)
# Requirement already satisfied: requests in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from contextily) (2.27.1)
# Requirement already satisfied: geographiclib<2,>=1.49 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from geopy->contextily) (1.52)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->contextily) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->contextily) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->contextily) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->contextily) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->contextily) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->contextily) (2.8.2)
# Requirement already satisfied: numpy>=1.17 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->contextily) (1.21.5)
# Requirement already satisfied: click>=3.0 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from mercantile->contextily) (8.0.4)
# Requirement already satisfied: affine in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from rasterio->contextily) (2.3.1)
# Requirement already satisfied: certifi in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from rasterio->contextily) (2021.10.8)
# Requirement already satisfied: attrs in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from rasterio->contextily) (21.4.0)
# Requirement already satisfied: setuptools in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from rasterio->contextily) (61.2.0)
# Requirement already satisfied: cligj>=0.5 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from rasterio->contextily) (0.7.2)
# Requirement already satisfied: click-plugins in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from rasterio->contextily) (1.1.1)
# Requirement already satisfied: snuggs>=1.4.1 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from rasterio->contextily) (1.4.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from requests->contextily) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from requests->contextily) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from requests->contextily) (1.26.9)
# Requirement already satisfied: six>=1.5 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->contextily) (1.16.0)
#
# [notice] A new release of pip is available: 23.0 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: cenpy==1.0.1 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (1.0.1)
# Requirement already satisfied: six in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from cenpy==1.0.1) (1.16.0)
# Requirement already satisfied: fuzzywuzzy in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from cenpy==1.0.1) (0.18.0)
# Requirement already satisfied: geopandas in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from cenpy==1.0.1) (0.8.2)
# Requirement already satisfied: pandas in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from cenpy==1.0.1) (1.4.2)
# Requirement already satisfied: libpysal in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from cenpy==1.0.1) (4.6.2)
# Requirement already satisfied: requests in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from cenpy==1.0.1) (2.27.1)
# Requirement already satisfied: numpy in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from cenpy==1.0.1) (1.21.5)
# Requirement already satisfied: rtree in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from cenpy==1.0.1) (0.9.7)
# Requirement already satisfied: pyproj>=2.2.0 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from geopandas->cenpy==1.0.1) (3.4.0)
# Requirement already satisfied: shapely in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from geopandas->cenpy==1.0.1) (1.8.4)
# Requirement already satisfied: fiona in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from geopandas->cenpy==1.0.1) (1.8.21)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from pandas->cenpy==1.0.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from pandas->cenpy==1.0.1) (2021.3)
# Requirement already satisfied: appdirs in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from libpysal->cenpy==1.0.1) (1.4.4)
# Requirement already satisfied: packaging in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from libpysal->cenpy==1.0.1) (21.3)
# Requirement already satisfied: jinja2 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from libpysal->cenpy==1.0.1) (2.11.3)
# Requirement already satisfied: beautifulsoup4 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from libpysal->cenpy==1.0.1) (4.11.1)
# Requirement already satisfied: scipy>=0.11 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from libpysal->cenpy==1.0.1) (1.7.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from requests->cenpy==1.0.1) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from requests->cenpy==1.0.1) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from requests->cenpy==1.0.1) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from requests->cenpy==1.0.1) (2021.10.8)
# Requirement already satisfied: soupsieve>1.2 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from beautifulsoup4->libpysal->cenpy==1.0.1) (2.3.1)
# Requirement already satisfied: munch in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from fiona->geopandas->cenpy==1.0.1) (2.5.0)
# Requirement already satisfied: attrs>=17 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from fiona->geopandas->cenpy==1.0.1) (21.4.0)
# Requirement already satisfied: click-plugins>=1.0 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from fiona->geopandas->cenpy==1.0.1) (1.1.1)
# Requirement already satisfied: setuptools in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from fiona->geopandas->cenpy==1.0.1) (61.2.0)
# Requirement already satisfied: click>=4.0 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from fiona->geopandas->cenpy==1.0.1) (8.0.4)
# Requirement already satisfied: cligj>=0.5 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from fiona->geopandas->cenpy==1.0.1) (0.7.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from jinja2->libpysal->cenpy==1.0.1) (2.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from packaging->libpysal->cenpy==1.0.1) (3.0.4)
#
# [notice] A new release of pip is available: 23.0 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# # The next line is importing libraries, takes 1 minute

# %%
import contextily
import geopandas
import cenpy
# %matplotlib inline
acs = cenpy.products.ACS(2017)

# %%
print(cenpy.__version__)
# Out:
# 1.0.1

# %%
vars_to_download = {
    "B02001_002E": "total_pop_white",     # Total white population
    "B02001_003E": "total_pop_black",     #Total black population
    "B01003_001E": "total_pop",           # Total population
    "B09019_001E": "hh_total",            # Total households
    "B15003_002E": "total_no_schooling",      # Total number of individuals who have not completed any schooling.
    "B01002_001E": "median_age",          # Median age
    "B19013_001E": "median_hh_income",     # Median household income 
    "B19058_001E": "SNAP_hh",              # Households receiving Food Stamps/SNAP 
    "B08015_001E": "access_to_vehicle"   # Workers over age 16 that drove alone to work by car, van, truck
}
vars_to_download_l = list(vars_to_download.keys())

# %% [markdown]
# http://cenpy-devs.github.io/cenpy/generated/cenpy.products.ACS.html

# %% [markdown]
# Note that we can add data from county, place, metropolitan statistical area.

# %% [markdown]
# Source: http://cenpy-devs.github.io/cenpy/generated/cenpy.products.ACS.html

# %% [markdown]
# # The next line is importing data from census, takes 2 mins

# %%
# Extracting census variables from Fulton County, GA
db0 = acs.from_county("Fulton, GA",
                  level="tract",
                  variables=vars_to_download_l
                 )
# Out:
# /Users/marta/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py:1981: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   result[:] = values
# /Users/marta/opt/anaconda3/lib/python3.9/site-packages/geopandas/_vectorized.py:143: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   aout[:] = out

# %%
db0.head()
# Out:
#          GEOID                                           geometry  \
# 0  13121010512  POLYGON ((-9412223.140 3972373.180, -9412195.5...
# 1  13121010507  POLYGON ((-9406193.400 3974540.920, -9406083.6...
# 2  13121007602  POLYGON ((-9403922.150 3989267.210, -9403919.5...
# 3  13121008700  POLYGON ((-9406355.710 4002622.120, -9406227.9...
# 4  13121004100  POLYGON ((-9399514.680 3994330.190, -9399403.0...
#
#    B01002_001E  B01003_001E  B02001_002E  B02001_003E  B08015_001E  \
# 0         28.3       6497.0        240.0       6061.0       2235.0
# 1         28.7       8190.0        348.0       7415.0       2340.0
# 2         46.0       2737.0         33.0       2671.0        850.0
# 3         33.4       5178.0        465.0       4699.0       1490.0
# 4         30.8       2127.0        154.0       1931.0        605.0
#
#    B09019_001E  B15003_002E  B19013_001E  B19058_001E  \
# 0       6497.0         15.0      30819.0       2472.0
# 1       8190.0          0.0      39190.0       2694.0
# 2       2737.0         29.0      34136.0       1026.0
# 3       5178.0         96.0      29583.0       2362.0
# 4       2127.0         21.0      38519.0        662.0
#
#                                           NAME state county   tract
# 0  Census Tract 105.12, Fulton County, Georgia    13    121  010512
# 1  Census Tract 105.07, Fulton County, Georgia    13    121  010507
# 2   Census Tract 76.02, Fulton County, Georgia    13    121  007602
# 3      Census Tract 87, Fulton County, Georgia    13    121  008700
# 4      Census Tract 41, Fulton County, Georgia    13    121  004100

# %%
db0.shape ##number of rows gives the number of tracts extracted
# Out:
# (204, 15)

# %%
## Droping rows with NA fields
#db.loc[:,vars_to_download].dropna(axis=0)
db = db0.dropna(axis=0)

# %%
db.describe()
# Out:
#        B01002_001E   B01003_001E   B02001_002E   B02001_003E  B08015_001E  \
# count   201.000000    201.000000    201.000000    201.000000   201.000000
# mean     36.058706   5013.880597   2259.756219   2211.144279  1851.243781
# std       6.665083   2948.400801   2157.234288   2614.447923  1263.544200
# min      12.400000   1075.000000      0.000000     29.000000   200.000000
# 25%      32.400000   2645.000000    263.000000    558.000000   810.000000
# 50%      35.400000   4478.000000   1857.000000   1369.000000  1630.000000
# 75%      40.300000   6282.000000   3834.000000   2491.000000  2510.000000
# max      54.800000  17958.000000  12255.000000  16075.000000  6555.000000
#
#         B09019_001E  B15003_002E   B19013_001E  B19058_001E
# count    201.000000   201.000000     201.00000   201.000000
# mean    5013.880597    24.497512   67063.99005  1948.955224
# std     2948.400801    30.528859   42621.31102  1081.882837
# min     1075.000000     0.000000    9815.00000   171.000000
# 25%     2645.000000     0.000000   31192.00000  1104.000000
# 50%     4478.000000    16.000000   56991.00000  1844.000000
# 75%     6282.000000    33.000000   93580.00000  2615.000000
# max    17958.000000   196.000000  200179.00000  6228.000000

# %%
##Option fill NA with column mean
#filler = lambda col: col.fillna(col.mean())
#db.loc[:, vars_to_download] = db.loc[:, vars_to_download]\
#                                .apply(filler)

# %% [markdown]
# ## Rename columns with intuitive names

# %%
db = db.rename(columns=vars_to_download)

# %%
db.head()
# Out:
#          GEOID                                           geometry  median_age  \
# 0  13121010512  POLYGON ((-9412223.140 3972373.180, -9412195.5...        28.3
# 1  13121010507  POLYGON ((-9406193.400 3974540.920, -9406083.6...        28.7
# 2  13121007602  POLYGON ((-9403922.150 3989267.210, -9403919.5...        46.0
# 3  13121008700  POLYGON ((-9406355.710 4002622.120, -9406227.9...        33.4
# 4  13121004100  POLYGON ((-9399514.680 3994330.190, -9399403.0...        30.8
#
#    total_pop  total_pop_white  total_pop_black  access_to_vehicle  hh_total  \
# 0     6497.0            240.0           6061.0             2235.0    6497.0
# 1     8190.0            348.0           7415.0             2340.0    8190.0
# 2     2737.0             33.0           2671.0              850.0    2737.0
# 3     5178.0            465.0           4699.0             1490.0    5178.0
# 4     2127.0            154.0           1931.0              605.0    2127.0
#
#    total_no_schooling  median_hh_income  SNAP_hh  \
# 0                15.0           30819.0   2472.0
# 1                 0.0           39190.0   2694.0
# 2                29.0           34136.0   1026.0
# 3                96.0           29583.0   2362.0
# 4                21.0           38519.0    662.0
#
#                                           NAME state county   tract
# 0  Census Tract 105.12, Fulton County, Georgia    13    121  010512
# 1  Census Tract 105.07, Fulton County, Georgia    13    121  010507
# 2   Census Tract 76.02, Fulton County, Georgia    13    121  007602
# 3      Census Tract 87, Fulton County, Georgia    13    121  008700
# 4      Census Tract 41, Fulton County, Georgia    13    121  004100

# %%
db.shape
# Out:
# (201, 15)

# %% [markdown]
# ## Calculates areas, and percentages

# %%
db["area_sqkm"] = db.to_crs(epsg=5070).area / 1e6

# %%
db["pct_no_schooling"] = db["total_no_schooling"] / \
                  (db["total_pop"] + \
                   (db["total_pop"]==0) * 1
                  )

# %%
db["pct_black"] = db["total_pop_black"] / \
                  (db["total_pop"] + \
                   (db["total_pop"]==0) * 1
                  )

# %%
db["pct_white"] = db["total_pop_white"] / \
                  (db["total_pop"] + \
                   (db["total_pop"]==0) * 1
                  )

# %%
db["pct_SNAP"] = db["SNAP_hh"] / \
                  (db["hh_total"] + \
                   (db["hh_total"]==0) * 1
                  )

# %%
db.head()  ##shows the new names and the new columns
# Out:
#          GEOID                                           geometry  median_age  \
# 0  13121010512  POLYGON ((-9412223.140 3972373.180, -9412195.5...        28.3
# 1  13121010507  POLYGON ((-9406193.400 3974540.920, -9406083.6...        28.7
# 2  13121007602  POLYGON ((-9403922.150 3989267.210, -9403919.5...        46.0
# 3  13121008700  POLYGON ((-9406355.710 4002622.120, -9406227.9...        33.4
# 4  13121004100  POLYGON ((-9399514.680 3994330.190, -9399403.0...        30.8
#
#    total_pop  total_pop_white  total_pop_black  access_to_vehicle  hh_total  \
# 0     6497.0            240.0           6061.0             2235.0    6497.0
# 1     8190.0            348.0           7415.0             2340.0    8190.0
# 2     2737.0             33.0           2671.0              850.0    2737.0
# 3     5178.0            465.0           4699.0             1490.0    5178.0
# 4     2127.0            154.0           1931.0              605.0    2127.0
#
#    total_no_schooling  median_hh_income  SNAP_hh  \
# 0                15.0           30819.0   2472.0
# 1                 0.0           39190.0   2694.0
# 2                29.0           34136.0   1026.0
# 3                96.0           29583.0   2362.0
# 4                21.0           38519.0    662.0
#
#                                           NAME state county   tract  \
# 0  Census Tract 105.12, Fulton County, Georgia    13    121  010512
# 1  Census Tract 105.07, Fulton County, Georgia    13    121  010507
# 2   Census Tract 76.02, Fulton County, Georgia    13    121  007602
# 3      Census Tract 87, Fulton County, Georgia    13    121  008700
# 4      Census Tract 41, Fulton County, Georgia    13    121  004100
#
#    area_sqkm  pct_no_schooling  pct_black  pct_white  pct_SNAP
# 0   9.250028          0.002309   0.932892   0.036940  0.380483
# 1   6.944902          0.000000   0.905372   0.042491  0.328938
# 2   3.369943          0.010596   0.975886   0.012057  0.374863
# 3   7.761980          0.018540   0.907493   0.089803  0.456161
# 4   1.265632          0.009873   0.907851   0.072402  0.311236

# %%
db.describe() ### Calculates the statistics of the variables
# Out:
#        median_age     total_pop  total_pop_white  total_pop_black  \
# count  201.000000    201.000000       201.000000       201.000000
# mean    36.058706   5013.880597      2259.756219      2211.144279
# std      6.665083   2948.400801      2157.234288      2614.447923
# min     12.400000   1075.000000         0.000000        29.000000
# 25%     32.400000   2645.000000       263.000000       558.000000
# 50%     35.400000   4478.000000      1857.000000      1369.000000
# 75%     40.300000   6282.000000      3834.000000      2491.000000
# max     54.800000  17958.000000     12255.000000     16075.000000
#
#        access_to_vehicle      hh_total  total_no_schooling  median_hh_income  \
# count         201.000000    201.000000          201.000000         201.00000
# mean         1851.243781   5013.880597           24.497512       67063.99005
# std          1263.544200   2948.400801           30.528859       42621.31102
# min           200.000000   1075.000000            0.000000        9815.00000
# 25%           810.000000   2645.000000            0.000000       31192.00000
# 50%          1630.000000   4478.000000           16.000000       56991.00000
# 75%          2510.000000   6282.000000           33.000000       93580.00000
# max          6555.000000  17958.000000          196.000000      200179.00000
#
#            SNAP_hh   area_sqkm  pct_no_schooling   pct_black   pct_white  \
# count   201.000000  201.000000        201.000000  201.000000  201.000000
# mean   1948.955224    6.868056          0.005617    0.475436    0.430139
# std    1081.882837   15.799895          0.006590    0.370279    0.328201
# min     171.000000    0.393121          0.000000    0.008635    0.000000
# 25%    1104.000000    1.507334          0.000000    0.115736    0.069287
# 50%    1844.000000    3.369943          0.004020    0.350531    0.477724
# 75%    2615.000000    6.913723          0.008037    0.905372    0.735767
# max    6228.000000  185.117094          0.034422    0.990776    0.975895
#
#          pct_SNAP
# count  201.000000
# mean     0.399654
# std      0.096834
# min      0.041799
# 25%      0.336959
# 50%      0.387755
# 75%      0.447165
# max      0.711181

# %%
! rm -f atlanta_tracts.gpkg 
db.to_file("atlanta.gpkg", driver="GPKG")  ### Saves data in gpkg format
# Out:
# /Users/marta/opt/anaconda3/lib/python3.9/site-packages/geopandas/io/file.py:234: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,

# %% [markdown]
# ## After you save atlanta_tracts.gpkg you can start the code here

# %%
db = geopandas.read_file('atlanta.gpkg')
db.columns
# Out:
# Index(['GEOID', 'median_age', 'total_pop', 'total_pop_white',
#        'total_pop_black', 'access_to_vehicle', 'hh_total',
#        'total_no_schooling', 'median_hh_income', 'SNAP_hh', 'NAME', 'state',
#        'county', 'tract', 'area_sqkm', 'pct_no_schooling', 'pct_black',
#        'pct_white', 'pct_SNAP', 'geometry'],
#       dtype='object')

# %%
db.head()  ##shows the new names and the new columns
# Out:
#          GEOID  median_age  total_pop  total_pop_white  total_pop_black  \
# 0  13121010512        28.3     6497.0            240.0           6061.0
# 1  13121010507        28.7     8190.0            348.0           7415.0
# 2  13121007602        46.0     2737.0             33.0           2671.0
# 3  13121008700        33.4     5178.0            465.0           4699.0
# 4  13121004100        30.8     2127.0            154.0           1931.0
#
#    access_to_vehicle  hh_total  total_no_schooling  median_hh_income  SNAP_hh  \
# 0             2235.0    6497.0                15.0           30819.0   2472.0
# 1             2340.0    8190.0                 0.0           39190.0   2694.0
# 2              850.0    2737.0                29.0           34136.0   1026.0
# 3             1490.0    5178.0                96.0           29583.0   2362.0
# 4              605.0    2127.0                21.0           38519.0    662.0
#
#                                           NAME state county   tract  \
# 0  Census Tract 105.12, Fulton County, Georgia    13    121  010512
# 1  Census Tract 105.07, Fulton County, Georgia    13    121  010507
# 2   Census Tract 76.02, Fulton County, Georgia    13    121  007602
# 3      Census Tract 87, Fulton County, Georgia    13    121  008700
# 4      Census Tract 41, Fulton County, Georgia    13    121  004100
#
#    area_sqkm  pct_no_schooling  pct_black  pct_white  pct_SNAP  \
# 0   9.250028          0.002309   0.932892   0.036940  0.380483
# 1   6.944902          0.000000   0.905372   0.042491  0.328938
# 2   3.369943          0.010596   0.975886   0.012057  0.374863
# 3   7.761980          0.018540   0.907493   0.089803  0.456161
# 4   1.265632          0.009873   0.907851   0.072402  0.311236
#
#                                             geometry
# 0  POLYGON ((-9412223.140 3972373.180, -9412195.5...
# 1  POLYGON ((-9406193.400 3974540.920, -9406083.6...
# 2  POLYGON ((-9403922.150 3989267.210, -9403919.5...
# 3  POLYGON ((-9406355.710 4002622.120, -9406227.9...
# 4  POLYGON ((-9399514.680 3994330.190, -9399403.0...

# %%
db.shape
# Out:
# (201, 20)

# %% [markdown]
# ## Kmeans Clustering (Elbow Method and Silhouette Scores)

# %%
pip install seaborn  #Package for plot styles
# Out:
# Requirement already satisfied: seaborn in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (0.11.2)
# Requirement already satisfied: pandas>=0.23 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from seaborn) (1.4.2)
# Requirement already satisfied: numpy>=1.15 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from seaborn) (1.21.5)
# Requirement already satisfied: scipy>=1.0 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from seaborn) (1.7.3)
# Requirement already satisfied: matplotlib>=2.2 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from seaborn) (3.5.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (1.3.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (9.0.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (4.25.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.23->seaborn) (2021.3)
# Requirement already satisfied: six>=1.5 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
#
# [notice] A new release of pip is available: 23.0 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import libpysal.weights.set_operations as Wsets
from libpysal.weights import Queen, KNN
import seaborn 
import pandas as pd
import geopandas 
import numpy
from sklearn.cluster import KMeans, AgglomerativeClustering
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pip install mapclassify
# Out:
# Requirement already satisfied: mapclassify in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (2.4.3)
# Requirement already satisfied: scipy>=1.0 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from mapclassify) (1.7.3)
# Requirement already satisfied: scikit-learn in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from mapclassify) (1.0.2)
# Requirement already satisfied: numpy>=1.3 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from mapclassify) (1.21.5)
# Requirement already satisfied: pandas>=1.0 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from mapclassify) (1.4.2)
# Requirement already satisfied: networkx in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from mapclassify) (2.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.0->mapclassify) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.0->mapclassify) (2021.3)
# Requirement already satisfied: joblib>=0.11 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->mapclassify) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->mapclassify) (2.2.0)
# Requirement already satisfied: six>=1.5 in /Users/marta/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=1.0->mapclassify) (1.16.0)
#
# [notice] A new release of pip is available: 23.0 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Here we select the variables to analyze

# %%
cluster_variables =  [
    'pct_white',          # Percent of tract population that is white
    'pct_black',          # Percent of tract population that is black
    'pct_no_schooling',       # Percent of tract population with no schooling
    'pct_SNAP',
    'median_age',         # Median age of tract population
    'median_hh_income'    # Median household income
]

# %%
f, axs = plt.subplots(nrows=2, ncols=3, figsize=(12, 12))
# Make the axes accessible with single indexing
axs = axs.flatten()
# Start a loop over all the variables of interest
for i, col in enumerate(cluster_variables):
    # select the axis where the map will go
    ax = axs[i]
    # Plot the map
    db.plot(column=col, ax=ax, scheme='Quantiles', 
            linewidth=0, cmap='RdPu',legend=True,legend_kwds={'fontsize':'xx-small'})
    # Remove axis clutter
    ax.set_axis_off()
    # Set the axis title to the name of variable being plotted
    ax.set_title(col)
# Display the figure
plt.show()
# Out:
# /Users/marta/opt/anaconda3/lib/python3.9/site-packages/descartes/patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
# /Users/marta/opt/anaconda3/lib/python3.9/site-packages/descartes/patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
# /Users/marta/opt/anaconda3/lib/python3.9/site-packages/descartes/patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
# /Users/marta/opt/anaconda3/lib/python3.9/site-packages/descartes/patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
# /Users/marta/opt/anaconda3/lib/python3.9/site-packages/descartes/patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
# /Users/marta/opt/anaconda3/lib/python3.9/site-packages/descartes/patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([

# %% [markdown]
# ## Measuring spatial autocorrelations

# %%
w = Queen.from_dataframe(db)

# %%
w.islands
# Out:
# []

# %%
from pylab import rcParams
import numpy as np
import matplotlib as mpl
from matplotlib.ticker import FixedLocator, FixedFormatter

# %% [markdown]
# ## MEASURING VARIABLE CORRELATIONS

# %%
# Function to calculate correlation coefficient between two arrays
def corr(x, y, **kwargs):
    # Calculate the value
    coef = np.corrcoef(x, y)[0][1]
    # Make the label
    label = r'$\rho$ = ' + str(round(coef, 2))
    
    # Add the label to the plot
    ax = plt.gca()
    ax.annotate(label, xy = (0.2, 0.95), size = 20, xycoords = ax.transAxes)


grid = seaborn.PairGrid(db[cluster_variables])
# Map the plots to the locations

grid = grid.map_upper(plt.scatter, color = 'darkred')
grid = grid.map_upper(corr)
grid = grid.map_lower(seaborn.kdeplot, cmap = 'Reds')
grid = grid.map_diag(plt.hist, bins = 10, edgecolor =  'k', color = 'darkred');
mpl.rcParams["axes.labelsize"] = 20
mpl.rcParams["xtick.labelsize"] = 16
mpl.rcParams["ytick.labelsize"] = 20
plt.savefig('PairGrid.png')
plt.show()

# %% [markdown]
# ## ELBOW METHOD

# %%
robust_scale(db[cluster_variables])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [34], in <cell line: 1>()
# ----> 1 robust_scale(db[cluster_variables])
#
# NameError: name 'robust_scale' is not defined

# %%
from sklearn.preprocessing import robust_scale, scale

db_scaled = scale(db[cluster_variables]) 

Sum_of_squared_distances = []
K = range(1,7)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(db_scaled)
    Sum_of_squared_distances.append(km.inertia_)

# %%
plt.figure(figsize = (10,6))
ax = plt.gca()
plt.plot(K, Sum_of_squared_distances, linewidth = 2)
plt.plot(K, Sum_of_squared_distances, '.', c='r',markersize = 6)
plt.plot(K,[Sum_of_squared_distances[-1] for i in range(len(Sum_of_squared_distances))],'--',
         linewidth = 1.5, c = 'black')

plt.xlabel('Number of clusters', fontsize = 20)
plt.ylabel('Sum of squared distances', fontsize = 20)
plt.title('Variation of the sum of squared distances in function of the number of clusters', fontsize = 15, y = 1.05)
ax.yaxis.set_ticks_position('none')
ax.xaxis.set_ticks_position('none')
#plt.xticks(np.arange(1, 21, step=1))
ax.grid(True)
plt.show()

# %%
# Initialising KMeans instance
kmeans = KMeans(n_clusters=4)

# %%
numpy.random.seed(12)
# Running K-Means algorithm
k4cls = kmeans.fit(db_scaled)

# %%
k4cls.labels_

# %%
k4cls.cluster_centers_

# %%
k4cls.inertia_

# %%
k4cls.n_iter_

# %%
# Visualising clusters on the map

from matplotlib.colors import ListedColormap, LinearSegmentedColormap
cmapTrial = ListedColormap(["lightseagreen", "darkorange", "lawngreen", "purple"])
db['k4cls'] = k4cls.labels_
f, ax = plt.subplots(1, figsize=(9, 9))
db.plot(column='k4cls', cmap=cmapTrial, categorical=True, legend=True, linewidth=0, ax=ax)
ax.set_axis_off()
plt.axis('equal')
plt.title(r'Geodemographic Clusters (k-means, $k=4$)')
plt.show()
# Out:
# /Users/marta/opt/anaconda3/lib/python3.9/site-packages/descartes/patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([

# %%
# Grouping data table by cluster label and count observations
k4sizes = db.groupby('k4cls').size()
k4sizes
# Out:
# k4cls
# 0    78
# 1    60
# 2    42
# 3    21
# dtype: int64

# %%
db.shape
# Out:
# (201, 21)

# %%
# cardinality
_ = k4sizes.plot.bar()

# %%
# Dissolve areas by Cluster, aggregate by summing, and keep column for area
areas = db.dissolve(by='k4cls', aggfunc='sum')['area_sqkm']
areas
# Out:
# /Users/marta/opt/anaconda3/lib/python3.9/site-packages/geopandas/_vectorized.py:143: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   aout[:] = out
# k4cls
# 0    563.820364
# 1    195.716276
# 2    389.580768
# 3    231.361902
# Name: area_sqkm, dtype: float64

# %%
areas.plot.bar() #Area per cluster
# Out:
# <AxesSubplot:xlabel='k4cls'>

# %%
areas[0]/areas.sum() #area cluster 0
# Out:
# 0.40842362517099445

# %%
# Grouping table by cluster label
k4means = db.groupby('k4cls')[cluster_variables].mean()
k4means.T.round(3)
# Out:
# k4cls                     0          1           2          3
# pct_white             0.115      0.664       0.791      0.212
# pct_black             0.835      0.203       0.068      0.732
# pct_no_schooling      0.005      0.003       0.003      0.020
# pct_SNAP              0.355      0.480       0.362      0.411
# median_age           33.824     34.245      43.117     35.424
# median_hh_income  34702.333  72500.200  133439.786  38980.810

# %%
# Grouping table by cluster label, keep the variables used for clustering, and obtaining their descriptive summary
k4desc = db.groupby('k4cls')[cluster_variables].describe()
for cluster in k4desc.T:
    print('\n\t---------\n\tCluster %i'%cluster)
    print(k4desc.T[cluster].unstack())
# Out:
# 	---------
# 	Cluster 0
#                   count          mean           std          min  \
# pct_white          78.0      0.115025      0.125935     0.000000
# pct_black          78.0      0.835295      0.166341     0.191483
# pct_no_schooling   78.0      0.004753      0.003303     0.000000
# pct_SNAP           78.0      0.354543      0.083756     0.041799
# median_age         78.0     33.824359      7.130476    12.400000
# median_hh_income   78.0  34702.333333  14066.824062  9815.000000
#
#                            25%           50%           75%           max
# pct_white             0.021616      0.062827      0.163517      0.522292
# pct_black             0.769771      0.907714      0.950208      0.982610
# pct_no_schooling      0.002362      0.004802      0.006797      0.012458
# pct_SNAP              0.325437      0.354564      0.401030      0.562844
# median_age           30.125000     33.650000     38.025000     49.400000
# median_hh_income  25882.000000  30895.500000  43544.750000  79397.000000
#
# 	---------
# 	Cluster 1
#                   count          mean           std           min  \
# pct_white          60.0      0.663548      0.124604      0.373974
# pct_black          60.0      0.203140      0.109808      0.031127
# pct_no_schooling   60.0      0.003459      0.004040      0.000000
# pct_SNAP           60.0      0.480258      0.084793      0.298540
# median_age         60.0     34.245000      3.735783     24.800000
# median_hh_income   60.0  72500.200000  17083.067860  26032.000000
#
#                            25%           50%           75%            max
# pct_white             0.584419      0.677890      0.753412       0.899308
# pct_black             0.119194      0.177692      0.245934       0.568866
# pct_no_schooling      0.000000      0.002494      0.005905       0.020061
# pct_SNAP              0.419708      0.479783      0.528841       0.711181
# median_age           32.025000     33.950000     36.100000      43.800000
# median_hh_income  60477.750000  71904.000000  85437.250000  105197.000000
#
# 	---------
# 	Cluster 2
#                   count           mean           std           min  \
# pct_white          42.0       0.790836      0.141951      0.393494
# pct_black          42.0       0.067739      0.042718      0.008635
# pct_no_schooling   42.0       0.002903      0.004661      0.000000
# pct_SNAP           42.0       0.362432      0.047316      0.280559
# median_age         42.0      43.116667      4.375872     36.700000
# median_hh_income   42.0  133439.785714  30916.778486  94803.000000
#
#                             25%            50%            75%            max
# pct_white              0.705740       0.816027       0.908283       0.975895
# pct_black              0.030967       0.063041       0.094286       0.161907
# pct_no_schooling       0.000000       0.000394       0.003365       0.016016
# pct_SNAP               0.321625       0.358132       0.396527       0.454696
# median_age            39.850000      42.500000      45.425000      54.800000
# median_hh_income  106569.000000  122435.000000  154303.500000  200179.000000
#
# 	---------
# 	Cluster 3
#                   count          mean           std           min  \
# pct_white          21.0      0.212281      0.235039      0.009224
# pct_black          21.0      0.732200      0.281900      0.094180
# pct_no_schooling   21.0      0.020425      0.006079      0.009573
# pct_SNAP           21.0      0.411360      0.102368      0.270069
# median_age         21.0     35.423810      5.804128     24.900000
# median_hh_income   21.0  38980.809524  18175.525815  18030.000000
#
#                            25%           50%           75%           max
# pct_white             0.035685      0.089803      0.452030      0.780098
# pct_black             0.478890      0.897871      0.935215      0.990776
# pct_no_schooling      0.017544      0.019943      0.022371      0.034422
# pct_SNAP              0.336959      0.387755      0.447536      0.696725
# median_age           32.700000     34.700000     38.300000     48.800000
# median_hh_income  26066.000000  34286.000000  42159.000000  84350.000000

# %%
# Index db on cluster ID
tidy_db = db.set_index('k4cls')
tidy_db = tidy_db[cluster_variables]
tidy_db = tidy_db.stack()
tidy_db = tidy_db.reset_index()
tidy_db = tidy_db.rename(columns={
                        'level_1': 'Attribute', 
                        0: 'Values'})
tidy_db
# Out:
#       k4cls         Attribute         Values
# 0         0         pct_white       0.036940
# 1         0         pct_black       0.932892
# 2         0  pct_no_schooling       0.002309
# 3         0          pct_SNAP       0.380483
# 4         0        median_age      28.300000
# ...     ...               ...            ...
# 1201      2         pct_black       0.058972
# 1202      2  pct_no_schooling       0.000000
# 1203      2          pct_SNAP       0.365375
# 1204      2        median_age      41.500000
# 1205      2  median_hh_income  104164.000000
#
# [1206 rows x 3 columns]

# %%
# Setup the facets
seaborn.set(font_scale=2.2) 
seaborn. set_style(style='white')
color = {0:"lightseagreen", 1:"darkorange", 2:"lawngreen", 3:"purple"}
facets = seaborn.FacetGrid(data=tidy_db, col='Attribute', palette=color, hue='k4cls', \
                  sharey=False, sharex=False, aspect=3, col_wrap=2)
_ = facets.map(seaborn.kdeplot, 'Values', shade=False).add_legend(fontsize=30)
facets.legend.set_title(' ')
facets.set_axis_labels("Value","Density",fontsize=25)

# %% [markdown]
# ## PCA ANALYSYS

# %%
from sklearn.decomposition import PCA

# %%
number_c=6
pca = PCA(n_components=number_c)  ##Decide the number of components
pca.fit(db_scaled) ### Executes the PCA
# Out:
# PCA(n_components=6)

# %%
projected_data = pca.fit_transform(db_scaled)
print("The shape of the initial data is:",db_scaled.shape)
print("The shape of the projected data is:",projected_data.shape)
# Out:
# The shape of the initial data is: (201, 6)
# The shape of the projected data is: (201, 6)

# %%
print(pca.explained_variance_ratio_[0:6])
# Out:
# [0.51990482 0.17009531 0.16431457 0.11798821 0.02355433 0.00414276]

# %% [markdown]
# ## Add here the PCA using code from RealityMining_Sept20.ipynb
